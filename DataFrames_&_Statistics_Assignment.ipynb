# %% [markdown]
# <a href="https://colab.research.google.com/github/Santgupt/Python-Practice/blob/master/DataFrames_%26_Statistics_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [80, 90, 35, 70, 93, 70, 45, 40, 88, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'no']}

exam = pd.DataFrame(exam_data)
exam
# Out:
#         name  score  attempts qualify
# 0  Anastasia     80         1     yes
# 1       Dima     90         3     yes
# 2  Katherine     35         2      no
# 3      James     70         3     yes
# 4      Emily     93         2     yes
# 5    Michael     70         3     yes
# 6    Matthew     45         1      no
# 7      Laura     40         1      no
# 8      Kevin     88         2     yes
# 9      Jonas     19         1      no

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   score     10 non-null     int64
#  2   attempts  10 non-null     int64
#  3   qualify   10 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 448.0+ bytes

# %%
exam.shape
# Out:
# (10, 4)

# %%
exam.describe()
# Out:
#           score   attempts
# count  10.00000  10.000000
# mean   63.00000   1.900000
# std    26.27631   0.875595
# min    19.00000   1.000000
# 25%    41.25000   1.000000
# 50%    70.00000   2.000000
# 75%    86.00000   2.750000
# max    93.00000   3.000000

# %%
exam.columns
# Out:
# Index(['name', 'score', 'attempts', 'qualify', 'mean'], dtype='object')

# %%
exam
# Out:
#         name  score  attempts qualify
# 0  Anastasia     80         1     yes
# 1       Dima     90         3     yes
# 2  Katherine     35         2      no
# 3      James     70         3     yes
# 4      Emily     93         2     yes
# 5    Michael     70         3     yes
# 6    Matthew     45         1      no
# 7      Laura     40         1      no
# 8      Kevin     88         2     yes
# 9      Jonas     19         1      no

# %%
exam.sort_values('score',ascending=False)
# Out:
#         name  score  attempts qualify
# 4      Emily     93         2     yes
# 1       Dima     90         3     yes
# 8      Kevin     88         2     yes
# 0  Anastasia     80         1     yes
# 3      James     70         3     yes
# 5    Michael     70         3     yes
# 6    Matthew     45         1      no
# 7      Laura     40         1      no
# 2  Katherine     35         2      no
# 9      Jonas     19         1      no

# %%
exam.sort_values(['score','name'],ascending=False)
# Out:
#         name  score  attempts qualify
# 4      Emily     93         2     yes
# 1       Dima     90         3     yes
# 8      Kevin     88         2     yes
# 0  Anastasia     80         1     yes
# 5    Michael     70         3     yes
# 3      James     70         3     yes
# 6    Matthew     45         1      no
# 7      Laura     40         1      no
# 2  Katherine     35         2      no
# 9      Jonas     19         1      no

# %%
exam
# Out:
#         name  score  attempts qualify
# 0  Anastasia     80         1     yes
# 1       Dima     90         3     yes
# 2  Katherine     35         2      no
# 3      James     70         3     yes
# 4      Emily     93         2     yes
# 5    Michael     70         3     yes
# 6    Matthew     45         1      no
# 7      Laura     40         1      no
# 8      Kevin     88         2     yes
# 9      Jonas     19         1      no

# %%
exam.loc[:,('name','qualify')]
# Out:
#         name qualify
# 0  Anastasia     yes
# 1       Dima     yes
# 2  Katherine      no
# 3      James     yes
# 4      Emily     yes
# 5    Michael     yes
# 6    Matthew      no
# 7      Laura      no
# 8      Kevin     yes
# 9      Jonas      no

# %%
exam[(exam['score']>=50)]
# Out:
#         name  score  attempts qualify
# 0  Anastasia     80         1     yes
# 1       Dima     90         3     yes
# 3      James     70         3     yes
# 4      Emily     93         2     yes
# 5    Michael     70         3     yes
# 8      Kevin     88         2     yes

# %%
exam
# Out:
#         name  score  attempts qualify
# 0  Anastasia     80         1     yes
# 1       Dima     90         3     yes
# 2  Katherine     35         2      no
# 3      James     70         3     yes
# 4      Emily     93         2     yes
# 5    Michael     70         3     yes
# 6    Matthew     45         1      no
# 7      Laura     40         1      no
# 8      Kevin     88         2     yes
# 9      Jonas     19         1      no

# %%
exam[(exam['qualify']=='yes')]
# Out:
#         name  score  attempts qualify
# 0  Anastasia     80         1     yes
# 1       Dima     90         3     yes
# 3      James     70         3     yes
# 4      Emily     93         2     yes
# 5    Michael     70         3     yes
# 8      Kevin     88         2     yes

# %%
exam[exam['attempts'].isin([1])]
# Out:
#         name  score  attempts qualify
# 0  Anastasia     80         1     yes
# 6    Matthew     45         1      no
# 7      Laura     40         1      no
# 9      Jonas     19         1      no

# %%
exam['mean'] = exam['score']/2

# %%
exam
# Out:
#         name  score  attempts qualify  mean
# 0  Anastasia     80         1     yes  40.0
# 1       Dima     90         3     yes  45.0
# 2  Katherine     35         2      no  17.5
# 3      James     70         3     yes  35.0
# 4      Emily     93         2     yes  46.5
# 5    Michael     70         3     yes  35.0
# 6    Matthew     45         1      no  22.5
# 7      Laura     40         1      no  20.0
# 8      Kevin     88         2     yes  44.0
# 9      Jonas     19         1      no   9.5

# %%
exam1=exam[exam['score']>=40]

# %%
exam1
# Out:
#         name  score  attempts qualify mean
# 0  Anastasia     80         1     yes    0
# 1       Dima     90         3     yes    0
# 3      James     70         3     yes    0
# 4      Emily     93         2     yes    0
# 5    Michael     70         3     yes    0
# 6    Matthew     45         1      no    0
# 7      Laura     40         1      no    0
# 8      Kevin     88         2     yes    0

# %%
exam1.sort_values('attempts')
# Out:
#         name  score  attempts qualify mean
# 0  Anastasia     80         1     yes    0
# 6    Matthew     45         1      no    0
# 7      Laura     40         1      no    0
# 4      Emily     93         2     yes    0
# 8      Kevin     88         2     yes    0
# 1       Dima     90         3     yes    0
# 3      James     70         3     yes    0
# 5    Michael     70         3     yes    0

# %%
exam1[['name','score','attempts']]
# Out:
#         name  score  attempts
# 0  Anastasia     80         1
# 1       Dima     90         3
# 3      James     70         3
# 4      Emily     93         2
# 5    Michael     70         3
# 6    Matthew     45         1
# 7      Laura     40         1
# 8      Kevin     88         2
